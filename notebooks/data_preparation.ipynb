# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Missing values
#
# There are no missing values in the data as checked during the data understanding stage.

# %% [markdown]
# ### Duplicate values

# %% [markdown]
# There are no duplicates in the data as checked in the data understanding stage.

# %% [markdown]
# ### Outlier detection

# %%
import pandas as pd

df = pd.read_csv("../data/diabd.csv")

df.head()
# Out:
#    age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 0   42  Female          66          110            73     5.88    1.65
# 1   35  Female          60          125            68     5.71    1.47
# 2   62  Female          57          127            74     6.85    1.52
# 3   73    Male          55          193           112     6.28    1.63
# 4   68  Female          71          150            81     5.71    1.42
#
#    weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# 0    70.2  25.75                0             0                    0
# 1    42.5  19.58                0             0                    0
# 2    47.0  20.24                0             0                    0
# 3    57.4  21.72                0             0                    0
# 4    36.0  17.79                0             0                    0
#
#    cardiovascular_disease  stroke diabetic
# 0                       0       0       No
# ...

# %%
import seaborn as sns

sns.boxplot(x=df['bmi'])
# Out:
# <Axes: xlabel='bmi'>

# %%
df.sort_values(by='bmi', ascending=False)
# Out:
#       age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 152    24    Male          63          165            89     4.89    0.36
# 885    75  Female          71          200            89     7.24    0.64
# 3378   28  Female          84          121            96    14.49    1.35
# 2293   65  Female          67          196           108     6.25    1.22
# 991    65    Male          54          163            94     4.03    1.22
# ...   ...     ...         ...          ...           ...      ...     ...
# 3120   65  Female          97          166            92     8.14    1.63
# 3313   30  Female          96           86            63     6.31    1.57
# 2392   70  Female          73          139            73     6.16    1.42
# 1731   70    Male          65          149            98    10.43    1.63
# 1279   46  Female         104          100            59    12.00    1.57
#
#       weight     bmi  family_diabetes  hypertensive  family_hypertension  \
# ...

# %%
df.sort_values(by='height', ascending=True)
# Out:
#       age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 152    24    Male          63          165            89     4.89    0.36
# 885    75  Female          71          200            89     7.24    0.64
# 4013   38  Female          72          134           100     6.00    0.99
# 3636   63  Female          72          142            90    15.00    1.19
# 3632   50  Female          80          136            81     5.00    1.19
# ...   ...     ...         ...          ...           ...      ...     ...
# 3543   47    Male          90          120            80     8.00    1.87
# 1039   51    Male          79          147            96    14.00    1.90
# 1963   70    Male          73          157           107     6.80    1.93
# 274    39  Female          86          135            81     8.00    1.95
# 140    40    Male          83          121            95     7.09    1.96
#
#       weight     bmi  family_diabetes  hypertensive  family_hypertension  \
# ...
